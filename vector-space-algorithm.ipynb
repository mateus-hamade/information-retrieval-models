# %% [markdown]
# ### Importando Bibliotecas

# %%
! python -m spacy download pt_core_news_sm
# Out:
# Collecting pt-core-news-sm==3.7.0
#   Using cached https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-3.7.0/pt_core_news_sm-3.7.0-py3-none-any.whl (13.0 MB)
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from pt-core-news-sm==3.7.0) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.7.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.25.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import glob
import re
import os
import unicodedata
import math

import nltk
from nltk.corpus        import stopwords
from nltk.tokenize      import word_tokenize
from nltk.stem.snowball import SnowballStemmer

import spacy
import pt_core_news_sm

nlp = spacy.load("pt_core_news_sm")
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ### Conectando ao Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Importando os documentos

# %%
def read_file(directory: str) -> str:
    file = open(directory, 'r')
    text = file.read()

    # index = text.find("Alternativas")

    # if index != -1:
    #     return text[:index].strip()
    # return text.strip()

    return text

# %%
print(read_file('/content/drive/MyDrive/Information retrieval/data/estrutura de dados [AV - 2](3 - GABARITO).txt'))
# Out:
# Algoritmos e Estrutura de Dados - Arvores
#
# Considere as seguintes assertivas sobre árvores binárias de busca e suas variantes:
#
# I. Em árvores AVL, a altura máxima é garantida em O(log n), onde n é o número de elementos na árvore.
# II. Árvores 2-3 são uma variação de árvores binárias de busca que permitem mais de dois filhos por nó.
# III. Em árvores B, a profundidade de busca é sempre O(log n), independentemente da distribuição dos dados.
# IV. Árvores de busca binária balanceadas como as AVL e as árvores rubro-negras garantem que a altura da árvore seja O(log n) no pior caso.
#
# Escolha a alternativa correta:
#
# A. Todas as assertivas estão corretas.
# B. Todas as assertivas estão incorretas.
# C. Apenas a assertiva I está correta.
# D. Apenas as assertivas II e III estão corretas.
# E. Apenas as assertivas III e IV estão corretas.

# %% [markdown]
# ### Tratamento dos dados

# %% [markdown]
# ##### Removendo acentuação

# %%
def remove_accents(text: str) -> str:
    nfkd = unicodedata.normalize('NFKD', text)

    filtered_text = ''.join([c for c in nfkd if not unicodedata.combining(c)])

    return filtered_text

# %%
print('Remoção de acentos: Análise ->', remove_accents('Análise'))
# Out:
# Remoção de acentos: Análise -> Analise

# %% [markdown]
# ##### Removendo caracteres especiais

# %%
def remove_special_characters(text: str) -> str:
    regex = re.compile(r'[^a-zA-Z0-9\s]')

    filtered_text = re.sub(regex, '', text)

    return filtered_text

# %%
print('Remoção de caracteres especiais: Guarda-chuva ->', remove_special_characters('Guarda-chuva'))
# Out:
# Remoção de caracteres especiais: Guarda-chuva -> Guardachuva

# %% [markdown]
# ##### Removendo *Stopwords*

# %%
def remove_stopwords(token: list[str]) -> list[str]:
    stop_words = stopwords.words('portuguese')

    filtered_token = [word for word in token if word not in stop_words]

    return filtered_token

# %%
print('Remoção de Stopwords: Todas aquelas pessoas -> ', remove_stopwords(['todas', 'aquelas', 'pessoas']))
# Out:
# Remoção de Stopwords: Todas aquelas pessoas ->  ['todas', 'pessoas']

# %% [markdown]
# ##### Aplicando a derivação de palavras

# %%
def lemmatization_words(token: list[str]) -> list[str]:
    terms = nlp(" ".join(token))

    lemmatized_tokens = [term.lemma_ for term in terms]

    return lemmatized_tokens

# %%
print('Aplicação da lematização:', lemmatization_words(['amigo', 'amigos', 'amigas']))
# Out:
# Aplicação da lematização: ['amigo', 'amigo', 'amiga']

# %% [markdown]
# #### Aplicando as funções nos documentos

# %%
def pre_processing(folder: str, document_token: dict, vocabulary: set) -> tuple:
    files = sorted(glob.glob(folder))

    for file in files:
        text = read_file(file)

        text = remove_accents(text)
        text = remove_special_characters(text)

        token = word_tokenize(text)
        token = remove_stopwords(token)
        token = lemmatization_words(token)

        vocabulary.update(token)

        document_token[os.path.basename(file)] = token

    return document_token, vocabulary

# %%
folder = '/content/drive/MyDrive/Information retrieval/data/*'

document_token, vocabulary = pre_processing(folder, {}, set())

# %%
print('banco de dados [AR - 2](2).txt:', document_token['banco de dados [AR - 2](2).txt'])
# Out:
# banco de dados [AR - 2](2).txt: ['banco', 'Dados', 'algebra', 'relacional', 'o', 'Algebra', 'Relacional', 'possuir', 'vario', 'operador', 'binario', 'dentre', 'operador', 'listar', 'abaixo', 'unico', 'NAO', 'binario', 'Alternativas', 'o', 'divisao', 'B', 'projecao', 'C', 'juncao', 'natural', 'D', 'juncao', 'externo', 'esquerdo', 'e', 'produto', 'cartesiano']

# %%
print('Vocabulário:', sorted(vocabulary))
# Out:
# Vocabulário: ['0', '0010010010', '002', '010', '0110110110', '012', '012157913', '020', '038jpg', '039jpg', '040jpg', '041jpg', '042jpg', '0pessoas10', '1', '10', '100', '10000', '1001001001', '101', '11', '1101101101', '12', '12c', '13', '130121579', '13452', '139510716', '14352', '15', '15423', '15432', '17', '19', '1FN', '1n', '2', '20', '20000', '2023', '2024', '20999', '23', '24', '25', '2FN', '2a', '3', '30', '32', '35', '396', '398', '3FN', '4', '40', '5', '6', '7', '8', '81', '839', '9', '951071613', '975211013', '98', '99', 'A', 'A1', 'A2', 'AND', 'APENAS', 'AS', 'AUTONOMOUSTRANSACTION', 'AVL', 'Abstracao', 'Abstract', 'Abstrair', 'Acelerando', 'AcelerandoPassear', 'Acessibilidade', 'AdelsonVelskii', 'Admitem', 'Advanced', 'Agregacao', 'Agrupar', 'Alem', 'Algebra', 'Algoritmos', 'Alimentar', 'Alternativas', 'Analise', 'Analista', 'Ano', 'Apenas', 'Aplicacao', 'Arvore', 'Arvores', 'Assinale', 'Assinalea', 'Assumindo', 'AutomovelVeiculo', 'B', 'B1', 'B2', 'B3', 'BPMN', 'BTREE', 'BY', 'Balanceamento', 'Banca', 'Basicos', 'Beneficios', 'BestFirst', 'Bibliotecas', 'Bitmap', 'Bogo', 'Bolha', 'BreadthFirst', 'BruteForce', 'Btree', 'Bubble', 'BubbleSort', 'Bucket', 'Buffer', 'C', 'CAMINHO', 'CCNPJ', 'CESGRANRIO', 'CIDADE', 'CNPJ', 'COMPRADO', 'COORDENADOR', 'CORRETO', 'CORRETOS', 'COUNTDISTINCT', 'COUNTnome', 'CPF', 'Caminho', 'Ccodproduto', 'Celula', 'Certo', 'Chave', 'Chaves', 'Classe', 'Classes', 'Cluster', 'Codigo', 'Colocao', 'Colunas', 'Complexidade', 'Compression', 'Concatenando', 'Conceitos', 'Considerandose', 'Considere', 'ConsoleWrite', 'ConsoleWriteAcelerar', 'ConsoleWriteMover', 'Cor', 'Correlacione', 'Correto', 'Criar', 'Cypher', 'D', 'DF', 'DFSGv', 'DFSGw', 'DISTANCIA', 'DISTINCT', 'Dado', 'Dados', 'Decorator', 'Define', 'Definicao', 'DepthFirst', 'Desenvolvimento', 'Devese', 'Diagrama', 'Dijkstra', 'Dinamicas', 'Divide', 'E', 'ER', 'ESCOLA', 'ET', 'EXCEPTION', 'EXCETO', 'Eclipse', 'Educacao', 'Encapsulamento', 'EntidadeRelacionamento', 'Entrada', 'Errado', 'Escolha', 'Escritos', 'Estados', 'Estao', 'Estouro', 'Estrutura', 'Exclusao', 'Existem', 'F', 'FCNPJ', 'FIFO', 'FORNECEDOR', 'FROM', 'Falamos', 'Falha', 'Falso', 'Fault', 'Filas', 'Filhos', 'Flexibilidade', 'Forint', 'Ftipo', 'Funcoes', 'FuscaAutomovel', 'G', 'G1', 'GCALLBACK', 'GROUP', 'GT', 'GTK', 'GTKCONTAINER', 'GTKWINDOW', 'GTKWINDOWTOPLEVEL', 'Gnome', 'Graficamente', 'Grafo', 'Grafos', 'GtkWinget', 'Gtkinit', 'Gtkmainquit', 'Gtkwindgetshowall', 'H', 'HAVING', 'Ha', 'Hamiltoniano', 'Hash', 'Heap', 'Heapsort', 'Heranca', 'Herdar', 'Heuristicas', 'I', 'IDEs', 'II', 'III', 'INCORRETA', 'INCORRETO', 'IPEA', 'IV', 'Imagem', 'Incorreto', 'Informacao', 'Insercao', 'Inserindo', 'Insertion', 'Instancia', 'Interface', 'Introducao', 'Invariante', 'JUNTE', 'Java', 'Joao', 'Juncao', 'K1k', 'KM', 'L10', 'L4', 'L5', 'L9', 'LIFO', 'LOCALIDADE', 'LOCALIDADEidloc', 'Landis', 'LerParametros', 'Linguagens', 'Long', 'Loop', 'MAX', 'MER', 'MERGE', 'Main', 'Maxima', 'Media', 'Medida', 'Merge', 'Metodos', 'Modelo', 'Movendo', 'MovendoAcelerandoPasseando', 'Municipioresidencia', 'N', 'NAO', 'NULL', 'NULO', 'NetBeans', 'Not', 'Numero', 'O2n', 'O3n', 'OOP', 'Objetos', 'ObjetosPOO', 'Olog', 'On', 'On2', 'On3', 'Onlogn', 'Operacionais', 'Oracle', 'Ordem', 'Ordenacao', 'Orgao', 'Orientada', 'Overflow', 'P', 'PESSOA', 'PLSQL', 'POO', 'PR', 'PRAGMA', 'PRODUTO', 'PROFESSOR', 'PROJETE', 'Padrao', 'Parametros', 'Parcial', 'Passeando', 'Pcodproduto', 'Pesquisa', 'Planejamento', 'Polimorfismo', 'Ponteiros', 'Preservacao', 'Preto', 'Procedimentos', 'Processamento', 'Processos', 'Programacao', 'Projecao', 'Projeto', 'Propriedade', 'Prova', 'Prufer', 'Q2335144', 'Quick', 'R2Y', 'RA', 'RAISE', 'RAISEAPPLICATIONERROR', 'RB', 'RG', 'RS', 'RX', 'Radix', 'Raiz', 'Recursividade', 'Registre', 'Registro', 'Relacional', 'Relacione', 'Restricoes', 'Rotulo', 'S', 'S1', 'S2', 'S3', 'SC', 'SELECIONE', 'SELECT', 'SGBD', 'SGBDs', 'SORT', 'SPARQL', 'SQL', 'SUM', 'Sao', 'Schedule', 'Search', 'Security10', 'Se ...

# %% [markdown]
# ### Cálculo do TF-IDF

# %% [markdown]
# ###### Preparação para o cálculo de TF-IDF

# %%
class Node:
    def __init__(self, name: str, frequency: int):
        self.frequency = frequency
        self.name      = name
        self.next      = None

    def __str__(self):
        return f'[Documento: {self.name}, Frequência: {self.frequency}]'

class LinkedList:
    def __init__(self):
        self.head = None

    def print_list(self) -> None:
        current_node = self.head

        while current_node:
            print(current_node, end = " -> ")
            current_node = current_node.next

        print("[ ]")

    def get_document_list(self) -> list[Node]:
        array = []
        node = self.head

        while node:
            array.append(node)
            node = node.next

        return array

    def append_document(self, name : str, frequency : int) -> None:
        new_node = Node(name, frequency)

        if self.head is None:
            self.head = new_node
            return

        last_node = self.head

        while last_node.next:
            last_node = last_node.next

        last_node.next = new_node

# %% [markdown]
# ###### Geração da matriz de termo-frequência: $\text{TF}_{ij} = 1 + \log_2 F_{ij}$

# %%
def calculate_term_frequency(term_frequency: dict) -> dict:
    for name, token in document_token.items():
        for term in set(token):
            frequency = 1 + math.log2(token.count(term))

            term_frequency[term].append_document(name, frequency)

    return term_frequency

# %%
print('Exemplo de termo-frequência [schedule]:')

term_frequency = calculate_term_frequency({term: LinkedList() for term in vocabulary})

for document in term_frequency['schedule'].get_document_list():
    print(document)
# Out:
# Exemplo de termo-frequência [schedule]:
# [Documento: banco de dados [PL-SQL - 3](2).txt, Frequência: 2.0]
# [Documento: banco de dados [PT - 3](2).txt, Frequência: 1.0]

# %% [markdown]
# ###### Geração da matriz de Frequência Inversa de Documento. $\text{IDF}_{i} =  \log_2 \frac {N} {n{i}}$

# %%
def calculate_IDF(term_frequency: dict, colletion_size: int, inverse_data_frequency: dict) -> dict:
    for term, posting in term_frequency.items():
        posting_size = len(posting.get_document_list())

        term_idf = math.log2(colletion_size / posting_size)

        inverse_data_frequency[term] = term_idf

    return inverse_data_frequency

# %%
print('Exemplo de frequência inversa de documento:')

inverse_data_frequency = calculate_IDF(term_frequency, 101, {})

print('schedule:', inverse_data_frequency['schedule'])
# Out:
# Exemplo de frequência inversa de documento:
# schedule: 5.658211482751795

# %% [markdown]
# ##### Geração da matriz de TF-IDF

# %%
def calculate_TF_IDF(term_frequency: dict, inverse_data_frequency: dict) -> dict:
    tf_idf = {term: LinkedList() for term in vocabulary}

    for term, posting in term_frequency.items():
        for node in posting.get_document_list():
            tf_idf[term].append_document(node.name, node.frequency * inverse_data_frequency[term])

    return tf_idf

# %%
print('Exemplo de TF-IDF:')

tf_idf = calculate_TF_IDF(term_frequency, inverse_data_frequency)

for document in tf_idf['schedule'].get_document_list():
    print(document)
# Out:
# Exemplo de TF-IDF:
# [Documento: banco de dados [PL-SQL - 3](2).txt, Frequência: 11.31642296550359]
# [Documento: banco de dados [PT - 3](2).txt, Frequência: 5.658211482751795]

# %% [markdown]
# ### Cálculo de similaridade

# %% [markdown]
# ###### Normalização

# %%
def normalize_vectors(tf_idf: dict) -> dict:
    document_norms = {}

    # Calculo da norma
    for term, posting in tf_idf.items():
        for node in posting.get_document_list():
            if node.name not in document_norms:
                document_norms[node.name] = 0

            document_norms[node.name] += node.frequency ** 2

    for name in document_norms:
        document_norms[name] = math.sqrt(document_norms[name])

    # Divisão do termo pela norma
    for term, posting in tf_idf.items():
        for node in posting.get_document_list():
            node.frequency /= document_norms[node.name]

    return document_norms

# %%
print('Norma de cada documento: ')

document_norms = normalize_vectors(tf_idf)
print(document_norms)
# Out:
# Norma de cada documento:
# {'introducao a programacao [BB - 3](1).txt': 66.57535142308782, 'introducao a programacao [CB - 1](3).txt': 25.664911662461854, 'banco de dados [AR - 2](1).txt': 99.67177280807265, 'estrutura de dados [CB - 3](2 - GABARITO).txt': 58.198623949013204, 'introducao a programacao [CL- 3](1).txt': 47.575539658185605, 'grafos [CB - 2](2).txt': 52.803250522256384, 'estrutura de dados [MB - 2](1).txt': 67.48872783909773, 'estrutura de dados [MO - 1](4).txt': 59.058253285703195, 'grafos [CA - 3](1).txt': 26.497559468766408, 'grafos [CA - 3](2).txt': 25.001442577414046, 'grafos [CB - 1](2).txt': 25.079925745113698, 'grafos [CB - 2](4).txt': 55.08402501029105, 'introducao a programacao [CB - 1](7).txt': 26.79523031311188, 'introducao a programacao [CB - 3](1).txt': 52.249812138999516, 'introducao a programacao [CL - 3](2).txt': 56.59565066367739, 'banco de dados [MR - 2](8).txt': 71.21322855751586, 'banco de dados [MR - 3](1).txt': 43.15830605261829, 'banco de dados [MR - 3](2).txt': 54.62819999668022, 'estrutura de dados [MO - 2](1).txt': 52.318682296437316, 'introducao a programacao [PT- 2](2).txt': 41.88008647463916, 'introducao a programacao [TD- 2](1).txt': 53.264588777927734, 'banco de dados [MR - 1](7).txt': 40.16173196918867, 'estrutura de dados [AV - 2](1 - GABARITO).txt': 39.073117871174745, 'programacao orientada a objetos [CB - 2](5).txt': 45.78905011544475, 'estrutura de dados [FL - 3](1).txt': 47.26565337796369, 'estrutura de dados [MO - 1](2).txt': 22.612990516383757, 'grafos [CB - 3](2).txt': 53.2160204825107, 'banco de dados [MR - 2](9).txt': 73.35015943633879, 'banco de dados [PL-SQL - 2](3).txt': 50.67566359810785, 'programacao orientada a objetos [CB - 2](4).txt': 30.61302512503982, 'grafos [AL - 3](3).txt': 75.35306627465502, 'programacao orientada a objetos [CB - 3](2).txt': 26.576514553493297, 'grafos [AL - 3](2).txt': 79.4285773251329, 'banco de dados [MR - 2](11).txt': 42.48327291386599, 'banco de dados [MR - 1](5).txt': 75.9101969913425, 'estrutura de dados [CA - 1](1).txt': 27.893041678547007, 'estrutura de dados [CA - 2](2).txt': 47.46862833593937, 'estrutura de dados [FL - 3](2).txt': 46.8108487380024, 'grafos [CB - 3](4).txt': 27.48039010231689, 'introducao a programacao [CB - 1](1).txt': 35.68532344705123, 'introducao a programacao [CB - 1](10).txt': 33.50698156324674, 'introducao a programacao [CB - 1](4).txt': 40.13542869615741, 'introducao a programacao [CB - 1](5).txt': 29.696570288463533, 'introducao a programacao [CB - 1](6).txt': 27.90675489659039, 'programacao orientada a objetos [CB - 2](2).txt': 40.10598611660684, 'programacao orientada a objetos [CB - 2](7).txt': 62.45396782325809, 'programacao orientada a objetos [CB - 3](1).txt': 36.853356942378824, 'programacao orientada a objetos [CB - 2](8).txt': 49.02561099309395, 'banco de dados [MR - 3](3).txt': 44.077049279661935, 'banco de dados [CB- 2](1).txt': 46.90373489524562, 'estrutra de dados [CB - 1](1).txt': 35.520870326276246, 'estrutura de dados [AV - 2](2).txt': 29.00901543756601, 'estrutura de dados [FL - 3](3).txt': 46.009332564663005, 'estrutura de dados [MO - 1](1).txt': 35.016106494166365, 'estrutura de dados [MO - 1](3).txt': 36.86359134337536, 'grafos [CB - 1](3).txt': 24.75623353668883, 'grafos [CB - 2](5).txt': 44.34403618354021, 'introducao a programacao [CB - 3](2).txt': 68.21513982931685, 'programacao orientada a objetos [PL - 1](1).txt': 31.098612078338448, 'programacao orientada a objetos [PL - 1](2).txt': 35.881499366470784, 'grafos [AL - 3](1).txt': 53.502358084772716, 'introducao a programacao [CB - 1](2).txt': 40.99759650957772, 'banco de dados [MR - 1](6).txt': 70.83599940836217, 'estrutura de dados [CB - 3](1 - GABARITO).txt': 56.345299545499685, 'grafos [CB - 1](4).txt': 15.985664597604995, 'grafos [CB - 1](5).txt': 18.715320085018337, 'grafos [CB - 2](3).txt': 24.91049882260775, 'programacao orientada a objetos [CB - 2](6).txt': 52.79722829632061, 'banco de dados [PL-SQL - 3](2).txt': 63.27980653492707, 'banco de dados [ ...

# %% [markdown]
# ##### Similaridade entre dois documentos

# %%
def calculate_cosine_similarity(doc1, doc2):
    vector1 = {}
    vector2 = {}

    for term, posting in tf_idf.items():
        for node in posting.get_document_list():
            if node.name == doc1:
                vector1[term] = node.frequency
            if node.name == doc2:
                vector2[term] = node.frequency

    dot_product = 0

    for term in vector1:
        if term in vector2:
            dot_product += vector1[term] * vector2[term]

    return dot_product

# Exemplo de uso
doc1 = 'estrutura de dados [AV - 2](3 - GABARITO).txt'

similarity = {}

for documento in document_token.keys():
    similarity[documento] = calculate_cosine_similarity(doc1, documento)

# %%
dict(sorted(similarity.items(), key=lambda item: item[1], reverse=True))
# Out:
# {'estrutura de dados [AV - 2](3 - GABARITO).txt': 1.0000000000000007,
#  'estrutura de dados [AV - 2](4 - GABARITO).txt': 0.5531921045772443,
#  'estrutura de dados [CB - 3](2 - GABARITO).txt': 0.32236434508704126,
#  'estrutura de dados [AV - 2](1 - GABARITO).txt': 0.2438359391947934,
#  'programacao orientada a objetos [CB - 1](1).txt': 0.19352635489917375,
#  'estrutura de dados [CB - 3](1 - GABARITO).txt': 0.1273094749860528,
#  'estrutura de dados [CA - 2](1).txt': 0.12589544293695543,
#  'banco de dados [CB- 2](1).txt': 0.11921009338458627,
#  'banco de dados [PL-SQL - 3](1).txt': 0.10883500664471377,
#  'programacao orientada a objetos [CB - 3](4).txt': 0.1084811614370495,
#  'programacao orientada a objetos [CB - 2](7).txt': 0.10648237407259055,
#  'banco de dados [MR - 3](3).txt': 0.09794807278405915,
#  'programacao orientada a objetos [CB - 2](5).txt': 0.09231992223793364,
#  'grafos [AL - 3](3).txt': 0.08963875363099022,
#  'grafos [AL - 3](2).txt': 0.08775073417177665,
#  'estrutura de dados [CA - 1](1).txt': 0.07239371602181623,
#  'programacao orientada a objetos [CB - 3](3).txt': 0.0645707325423989,
#  'programacao orientada a objetos [CB - 2](6).txt': 0.06452595287914294,
#  'banco de dados [MR - 3](1).txt': 0.06356389303947022,
#  'estrutura de dados [AV - 2](2).txt': 0.0585433397166725,
#  'grafos [CB - 3](4).txt': 0.05741137214980854,
#  'grafos [AL - 3](1).txt': 0.05463059782047975,
#  'programacao orientada a objetos [CB - 2](2).txt': 0.0446188472135724,
#  'estrutura de dados [MB - 2](1).txt': 0.03993539483293698,
#  'grafos [CB - 3](1).txt': 0.038270135168936466,
#  'grafos [CB - 1](2).txt': 0.036278496754879375,
#  'grafos [CB - 1](5).txt': 0.035885126737685125,
#  'programacao orientada a objetos [CB - 1](4).txt': 0.03481614628367325,
#  'programacao orientada a objetos [CB - 3](6).txt': 0.03470849147056536,
#  'banco de dados [PT - 3](2).txt': 0.03240652805807012,
#  'estrutra de dados [CB - 1](1).txt': 0.03219599367905013,
#  'grafos [CB - 3](2).txt': 0.030120727028428124,
#  'programacao orientada a objetos [CB - 2](8).txt': 0.029177869763700865,
#  'estrutura de dados [MO - 1](2).txt': 0.02874603840931674,
#  'grafos [CB - 2](3).txt': 0.028379777136064807,
#  'grafos [CB - 2](1).txt': 0.028077049706096813,
#  'estrutura de dados [FL - 3](1).txt': 0.027346305960173057,
#  'programacao orientada a objetos [CB - 3](1).txt': 0.026115712346790037,
#  'banco de dados [MR - 2](11).txt': 0.025198132020040176,
#  'programacao orientada a objetos [CB - 2](1).txt': 0.023201727567450654,
#  'estrutura de dados [FL - 3](3).txt': 0.022750036431712098,
#  'estrutura de dados [MO - 1](4).txt': 0.021722452664276214,
#  'grafos [CB - 2](6).txt': 0.021692359530119856,
#  'grafos [CA - 3](2).txt': 0.020955201040915777,
#  'introducao a programacao [TD- 2](1).txt': 0.02051314347500047,
#  'banco de dados [MR - 2](9).txt': 0.019567307310973843,
#  'banco de dados [MR - 1](5).txt': 0.019110411917546935,
#  'estrutura de dados [FL - 3](2).txt': 0.019021545660664486,
#  'estrutura de dados [MO - 1](1).txt': 0.018744874769969295,
#  'estrutura de dados [MO - 1](3).txt': 0.018679609483091532,
#  'estrutura de dados [MO - 2](1).txt': 0.017331095811831603,
#  'estrutura de dados [CA - 2](2).txt': 0.01702771347474045,
#  'banco de dados [MR - 2](10).txt': 0.016520312665227563,
#  'banco de dados [PL-SQL - 2](3).txt': 0.014360163067614859,
#  'banco de dados [AR - 2](1).txt': 0.014262607302684367,
#  'programacao orientada a objetos [CL- 2](1).txt': 0.013529427108488434,
#  'banco de dados [PL-SQL - 3](2).txt': 0.01298926641632003,
#  'programacao orientada a objetos [CB - 1](2).txt': 0.012891147871238146,
#  'banco de dados [MR - 1](4).txt': 0.012344134363863082,
#  'grafos [CB - 2](2).txt': 0.012194898258068439,
#  'programacao orientada a objetos [CB - 1](3).txt': 0.011856511046869172,
#  'programacao orientada a objetos [CB - 3](2).txt': 0.011767276219308771,
#  'introducao a programacao [CB - 1](4).txt': 0.011710622941421396,
#  'programacao orientada a objetos [CB - 2](4).txt': 0.011407889984469559,
#  'programacao orientada a objetos [PL - 1](2).txt': 0.010526594728010477,
#  'introducao a programacao [CB - 3](2).txt': 0.010055543036831208,
#  'banco de dados [MR - 1](7).txt': 0.00990232150004623,
#  'estrutura de dados [FL - 1](1).txt': 0.00953327866378336,
#  'grafos [CA - 3](1).txt': 0.009290135719407,
#  'grafos [CB - 2](5).txt': 0.008049330480689154,
#  'introducao a programacao [CB - 1](10).txt': 0.008009095807932352,
#  'banco de dados [PT - 3](1).txt': 0.007536252336510285,
#  'grafos [CB - 1](4).txt': 0.007191372671522282,
#  'programacao orientada a objetos [CB - 3](5).txt': 0.00689255393286164,
#  'banco de dados [MR - 1](6).txt': 0.005275491930583195,
#  'introducao a programacao [CB - 2](3).txt': 0.005227385275984524,
#  'introducao a programacao [CB - 1](1).txt': 0.005018699576796589,
#  'introducao a programacao [CB - 1](2).txt': 0.0050090697893653,
#  'introducao a programacao [CB - 1](8).txt': 0.004430411336852689,
#  'introducao a programacao [CB - 1](7).txt': 0.004032475018312518,
#  'introducao a programacao [CL - 3](2).txt': 0.003628046995665883,
#  'introducao a programacao [CL- 3](1).txt': 0.00362654104700914,
#  'banco de dados [MR - 2](8).txt': 0.0035233298503208627,
#  'programacao orientada a objetos [PL - 1](1).txt': 0.0034387725451874287,
#  'introducao a programacao [BB - 3](1).txt': 0.0033277168174512114,
#  'banco de dados [MR - 3](2).txt': 0.0030781436474192157,
#  'introducao a programacao [CB - 2](1).txt': 0.0029754502863090213,
#  'introducao a programacao [CB - 3](1).txt': 0.00286796112330699,
#  'grafos [CB - 1](3).txt': 0.0023209151109397264,
#  'banco de dados [AR - 2](2).txt': 0.0018513199822225424,
#  'banco de dados [CB - 3](2).txt': 0.0015808038823870941,
#  'introducao a programacao [CB - 1](3).txt': 0.0014701129667682388,
#  'introducao a programacao [CB - 1](9).txt': 0.0014332978410154427,
#  'grafos [CB - 3](3).txt': 0.0012084147454422254,
#  'introducao a programacao [PT- 2](2).txt': 0.0008772689189225129,
#  'grafos [CB - 2](4).txt': 0.0006289973837798637,
#  'programacao orientada a objetos [CB - 2](3).txt': 5.014069943341175e-05,
#  'grafos [CB - 1](1).txt': 4.404583482429547e-05,
#  'introducao a programacao [CB - 1](5).txt': 3.7813128589858744e-05,
#  'introducao a programacao [CB - 1](6).txt': 4.755084979556237e-06,
#  'introducao a programacao [CB - 2](2).txt': 3.7098956978984324e-06}
