# %% [markdown]
# ### Importando Bibliotecas

# %%
! python -m spacy download pt_core_news_sm &> /dev/null

# %%
import glob
import re
import os
import unicodedata
import math

import nltk
from nltk.corpus        import stopwords
from nltk.tokenize      import word_tokenize
from nltk.stem.snowball import SnowballStemmer

from tabulate import tabulate

import spacy
import pt_core_news_sm

nlp = spacy.load("pt_core_news_sm")
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ### Conectando ao Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Importando os documentos

# %%
def read_file(directory: str) -> str:
    file = open(directory, 'r')
    text = file.read()

    return text

# %%
print(read_file('/content/drive/MyDrive/Information retrieval/data/estrutura de dados [AV - 2](3 - GABARITO).txt'))
# Out:
# Algoritmos e Estrutura de Dados - Arvores
#
# Considere as seguintes assertivas sobre árvores binárias de busca e suas variantes:
#
# I. Em árvores AVL, a altura máxima é garantida em O(log n), onde n é o número de elementos na árvore.
# II. Árvores 2-3 são uma variação de árvores binárias de busca que permitem mais de dois filhos por nó.
# III. Em árvores B, a profundidade de busca é sempre O(log n), independentemente da distribuição dos dados.
# IV. Árvores de busca binária balanceadas como as AVL e as árvores rubro-negras garantem que a altura da árvore seja O(log n) no pior caso.
#
# Alternativas:
#
# A. Todas as assertivas estão corretas.
# B. Todas as assertivas estão incorretas.
# C. Apenas a assertiva I está correta.
# D. Apenas as assertivas II e III estão corretas.
# E. Apenas as assertivas III e IV estão corretas.

# %% [markdown]
# ### Tratamento dos dados

# %% [markdown]
# ##### Removendo acentuação

# %%
def remove_accents(text: str) -> str:
    nfkd = unicodedata.normalize('NFKD', text)

    filtered_text = ''.join([c for c in nfkd if not unicodedata.combining(c)])

    return filtered_text

# %%
print('Remoção de acentos: Análise ->', remove_accents('Análise'))
# Out:
# Remoção de acentos: Análise -> Analise

# %% [markdown]
# ##### Removendo caracteres especiais

# %%
def remove_special_characters(text: str) -> str:
    regex = re.compile(r'[^a-zA-Z0-9\s]')

    filtered_text = re.sub(regex, '', text)

    return filtered_text

# %%
print('Remoção de caracteres especiais: Guarda-chuva ->', remove_special_characters('Guarda-chuva'))
# Out:
# Remoção de caracteres especiais: Guarda-chuva -> Guardachuva

# %% [markdown]
# ##### Convertendo para minúsculas

# %%
def convert_to_lowercase(text: str) -> str:
    return text.casefold()

# %%
print('Conversão para minúsculas: Estrutura de Dados ->', convert_to_lowercase('Estrutura de Dados'))
# Out:
# Conversão para minúsculas: Estrutura de Dados -> estrutura de dados

# %% [markdown]
# ##### Removendo *Stopwords*

# %%
def remove_stopwords(token: list[str]) -> list[str]:
    stop_words = stopwords.words('portuguese')

    filtered_token = [word for word in token if word not in stop_words]

    return filtered_token

# %%
print('Remoção de Stopwords: Todas aquelas pessoas -> ', remove_stopwords(['todas', 'aquelas', 'pessoas']))
# Out:
# Remoção de Stopwords: Todas aquelas pessoas ->  ['todas', 'pessoas']

# %% [markdown]
# ##### Aplicando a derivação de palavras

# %%
def lemmatization_words(token: list[str]) -> list[str]:
    terms = nlp(" ".join(token))

    lemmatized_tokens = [term.lemma_ for term in terms]

    return lemmatized_tokens

# %%
print('Aplicação da lematização:', lemmatization_words(['amigo', 'amigos', 'amigas']))
# Out:
# Aplicação da lematização: ['amigo', 'amigo', 'amiga']

# %%
def finding_unique_words_and_freq(dictionary : dict, token : list):
    for term in set(token):
        if term in dictionary.keys():
            dictionary[term] += token.count(term)
        else:
            dictionary[term] = token.count(term)

    return dictionary

# %% [markdown]
# #### Aplicando as funções nos documentos

# %%
def pre_processing(folder: str, document_token: dict, vocabulary: set) -> tuple:
    files = sorted(glob.glob(folder))

    for file in files:
        text = read_file(file)

        text = remove_accents(text)
        text = remove_special_characters(text)
        text = convert_to_lowercase(text)

        token = word_tokenize(text)
        token = remove_stopwords(token)
        token = lemmatization_words(token)

        vocabulary.update(token)

        document_token[os.path.basename(file)] = token

    return document_token, sorted(vocabulary)

# %%
folder = '/content/drive/MyDrive/Information retrieval/data/*'

document_token, vocabulary = pre_processing(folder, {}, set())

# %%
print('estrutura de dados [AV - 3](2 - GABARITO).txt:', document_token['estrutura de dados [AV - 3](2 - GABARITO).txt'])
# Out:
# estrutura de dados [AV - 3](2 - GABARITO).txt: ['algoritmos', 'estrutura', 'dar', 'arvor', 'considere', 'arvorir', 'rubronegrar', 'estrutura', 'dar', 'frequentemente', 'usar', 'implementar', 'arvor', 'busca', 'balancear', 'arvor', 'possuir', 'propriedade', 'unico', 'garantir', 'desempenho', 'eficiente', 'operacoes', 'insercao', 'exclusao', 'pesquisa', 'sobre', 'caracteristica', 'arvor', 'rubronegra', 'seguinte', 'afirmacoes', 'correta', 'alternativo', 'propriedade', 'balanceamento', 'arvore', 'rubronegra', 'manter', 'balanceamento', 'garantir', 'altura', 'qualquer', 'maximo', 'dois', 'vez', 'altura', 'curto', 'b', 'cor', 'arvore', 'rubronegrar', 'todo', 'vermelho', 'dever', 'ter', 'filho', 'preto', 'manter', 'assim', 'estrutura', 'balanceado', 'c', 'numerar', 'filho', 'arvor', 'rubronegro', 'sao', 'arvor', 'binaria', 'onde', 'cada', 'poder', 'ter', 'maximo', 'dois', 'filho', 'garantir', 'estrutura', 'ordenar', 'd', 'invariante', 'caminho', 'preto', 'arvore', 'rubronegrar', 'caminho', 'Raiz', 'ate', 'qualquer', 'folha', 'dever', 'ter', 'numero', 'preto', 'garantir', 'equilibrio', 'altura', 'caminho']

# %%
print('Vocabulário:', vocabulary)
# Out:
# Vocabulário: ['0', '0010010010', '002', '010', '0110110110', '012', '012157913', '020', '0pessoas10', '1', '10', '100', '10000', '1001001001', '101', '11', '1101101101', '12', '12c', '13', '130121579', '13452', '139510716', '14352', '15', '15423', '15432', '17', '19', '1fn', '1n', '2', '20', '20000', '20999', '23', '234', '24', '25', '2a', '2fn', '3', '30', '32', '35', '396', '398', '3fn', '4', '40', '5', '6', '7', '8', '81', '839', '9', '951071613', '975211013', '98', '99', 'A2', 'Abstract', 'Agregacao', 'Assinale', 'Autonomoustransaction', 'Avl', 'Bubble', 'Campos', 'Ccodproduto', 'Chaves', 'Classe', 'Classes', 'Cnpj', 'Codproduto', 'Colocao', 'Compilacao', 'Definicao', 'Escola', 'Escritos', 'Estado', 'Estados', 'Estrela', 'Fault', 'Fifo', 'Forint', 'From', 'Geral', 'Grafo', 'Grafos', 'Gravacao', 'Gsignalconnect', 'Gtkcontainer', 'Gtkcontaineradd', 'Gtkinit', 'Gtklabelnew', 'Gtkmainquit', 'Gtkwindgetshowall', 'Heuristicas', 'Insercao', 'Keya2', 'L5', 'Lista', 'Long', 'Loop', 'Main', 'Maxima', 'Media', 'Medida', 'Merge', 'Metodo', 'Not', 'Pcodproduto', 'R2y', 'Raiz', 'S1', 'Segmentation', 'Selecao', 'Selection', 'Sort', 'Termino', 'Transacoes', 'Valor', 'Void', 'W1x', 'W1y', 'W2x', 'W2y', 'Widgets', 'Window', 'a0', 'a1', 'a2', 'abaixo', 'abordagem', 'abstracao', 'abstracaor', 'abstrair', 'abstrata', 'abstratar', 'abstrato', 'acao', 'acarreta', 'acelerandopassear', 'acelerar', 'acessar', 'acessibilidade', 'acesso', 'aciclico', 'acima', 'acomodar', 'acoplamento', 'acordo', 'acrescentar', 'acronimo', 'adelsonvelskii', 'adequadamente', 'adequado', 'adiado', 'adicional', 'adjacente', 'administrar', 'admitar', 'adotar', 'advanced', 'aferir', 'afirmacoe', 'afirmacoes', 'afirmar', 'afirmativa', 'afirmativar', 'afirmativo', 'agregacao', 'agricultura', 'agrupar', 'ainda', 'ajudar', 'alcancar', 'alcancavel', 'aleatoriamente', 'aler', 'algebrar', 'algo', 'algoritmo', 'algoritmos', 'algum', 'alimentar', 'alterar', 'alternativa', 'alternativo', 'alto', 'altura', 'ambiguidade', 'ambos', 'analisar', 'analise', 'analiser', 'and', 'antigo', 'aparecer', 'apenas', 'aplicacao', 'aplicacoes', 'apo', 'apontar', 'apos', 'apresentar', 'apropriar', 'aproximadamente', 'arco', 'areo', 'aresta', 'arestas', 'aresto', 'arg', 'argc', 'argv', 'argv1', 'aritmetico', 'armazenagem', 'armazenamento', 'armazenar', 'arquivo', 'array', 'arvor', 'arvorar', 'arvore', 'arvorir', 'assertiva', 'assertivo', 'assim', 'assinale', 'assinalea', 'assinaler', 'assinatura', 'assincronamente', 'assincronos', 'associacao', 'associar', 'association', 'assumir', 'ate', 'atingir', 'ator', 'atravessar', 'atribuicao', 'atributo', 'atual', 'atualizacao', 'atualizar', 'aumentar', 'automovelveiculo', 'auxiliar', 'avaliacao', 'avancar', 'avl', 'b', 'b1', 'b10', 'b2', 'b3', 'b9', 'baixo', 'balanceado', 'balanceamento', 'balancear', 'banco', 'base', 'basear', 'basico', 'bdnab', 'beneficio', 'bestfirst', 'biblioteca', 'biblioteco', 'binar', 'binaria', 'binario', 'binding', 'bipartido', 'bit', 'bitmapr', 'bloco', 'bolho', 'bom', 'bpmn', 'brasileiro', 'breadthfirst', 'bruteforce', 'bst', 'btree', 'bucket', 'buffer', 'buffer10', 'busca', 'buscar', 'busco', 'by', 'c', 'cabecalho', 'cabo', 'cada', 'caixeiro', 'caixeiroviajante', 'caminho', 'campo', 'capacidade', 'caracter', 'caracteristica', 'caracteristicar', 'caracteristicas', 'caracteristico', 'caracterizado', 'cargo', 'cartesiano', 'casa', 'casesensitive', 'caso', 'causa', 'causar', 'ccnpj', 'celular', 'centralizar', 'certo', 'chamar', 'chame', 'char', 'character', 'chave', 'chefe', 'ciclo', 'ciclomaticar', 'ciclomatico', 'cidade', 'cima', 'cinco', 'circuito', 'circulo', 'class', 'classe', 'classes', 'classico', 'classificar', 'clausula', 'cluster', 'cnpj', 'cobertura', 'codescola', 'codescolaprof', 'codescolar', 'codificar', 'codigo', 'codmunicipiar', 'codmunicipio', 'codmunicipioresidenciar', 'codproduto', 'coesao', 'coincidir', 'coletar', 'coluna', 'colunar', 'comando', 'combinaas', 'commit', 'compactacao', 'comparacao', 'comparar', 'compa ...

# %% [markdown]
# ### Cálculo da frequência

# %% [markdown]
# ###### Preparação para o cálculo da frequência

# %%
class Node:
    def __init__(self, name: str, frequency: int):
        self.frequency = frequency
        self.name      = name
        self.next      = None

    def __str__(self):
        return f'[Documento: {self.name}, Frequência: {self.frequency}]'

class LinkedList:
    def __init__(self):
        self.head = None

    def print_list(self) -> None:
        current_node = self.head

        while current_node:
            print(current_node, end = " -> ")
            current_node = current_node.next

        print("[ ]")

    def get_document_list(self) -> list[Node]:
        array = []
        node = self.head

        while node:
            array.append(node)
            node = node.next

        return array

    def append_document(self, name : str, frequency : int) -> None:
        new_node = Node(name, frequency)

        if self.head is None:
            self.head = new_node
            return

        last_node = self.head

        while last_node.next:
            last_node = last_node.next

        last_node.next = new_node

# %% [markdown]
# ###### Geração da matriz de termo-frequência

# %%
def calculate_term_frequency(term_frequency: dict) -> dict:
    for name, token in document_token.items():
        for term in set(token):
            frequency = 1 + math.log2(token.count(term))

            term_frequency[term].append_document(name, frequency)

    return term_frequency

# %%
def normalize_TF(term_frequency: dict) -> dict:
    document_term_frequency = {}

    for term, posting in term_frequency.items():
        for node in posting.get_document_list():
            if node.name not in document_term_frequency:
                document_term_frequency[node.name] = []

            document_term_frequency[node.name].append(node.frequency)

    max_term_frequencies = {name: max(frequencies) for name, frequencies in document_term_frequency.items()}

    for term, posting in term_frequency.items():
        for node in posting.get_document_list():
            max_frequency = max_term_frequencies[node.name]

            if max_frequency > 0:
                node.frequency /= max_frequency

    return term_frequency

# %%
print('Exemplo de termo-frequência [schedule]:')

term_frequency = calculate_term_frequency({term: LinkedList() for term in vocabulary})
term_frequency = normalize_TF(term_frequency)

for document in term_frequency['schedule'].get_document_list():
    print(document)
# Out:
# Exemplo de termo-frequência [schedule]:
# [Documento: banco de dados [PL-SQL - 3](2).txt, Frequência: 0.6020599913279624]
# [Documento: banco de dados [PT - 3](2).txt, Frequência: 0.27894294565112987]

# %% [markdown]
# ###### Geração da matriz de Frequência Inversa de Documento. $\text{IDF}_{i} =  \log_2 \frac {N} {n{i}}$

# %%
def calculate_IDF(term_frequency: dict, collection_size: int, inverse_data_frequency: dict) -> dict:
    for term, posting in term_frequency.items():
        posting_size = len(posting.get_document_list())

        term_idf = math.log2(collection_size / posting_size)

        inverse_data_frequency[term] = term_idf

    return inverse_data_frequency

# %%
def normalize_IDF(inverse_data_frequency: dict) -> dict:
    max_idf = max(inverse_data_frequency.values())

    for term, idf in inverse_data_frequency.items():
        inverse_data_frequency[term] = idf / max_idf

    return inverse_data_frequency

# %%
print('Exemplo de frequência inversa de documento:')

inverse_data_frequency = calculate_IDF(term_frequency, len(document_token), {})
inverse_data_frequency = normalize_IDF(inverse_data_frequency)

print('árvore:', inverse_data_frequency['arvore'])
# Out:
# Exemplo de frequência inversa de documento:
# árvore: 0.48153310957614376

# %% [markdown]
# ##### Geração da matriz de TF-IDF

# %%
def calculate_TF_IDF(term_frequency: dict, inverse_data_frequency: dict) -> dict:
    tf_idf = {term: LinkedList() for term in vocabulary}

    for term, posting in term_frequency.items():
        for node in posting.get_document_list():
            tf_idf[term].append_document(node.name, node.frequency * inverse_data_frequency[term])

    return tf_idf

# %%
print('Exemplo de TF-IDF:')

tf_idf = calculate_TF_IDF(term_frequency, inverse_data_frequency)

for document in tf_idf['schedule'].get_document_list():
    print(document)
# Out:
# Exemplo de TF-IDF:
# [Documento: banco de dados [PL-SQL - 3](2).txt, Frequência: 0.511828934332715]
# [Documento: banco de dados [PT - 3](2).txt, Frequência: 0.23713761530198416]

# %% [markdown]
# ### Cálculo da similaridade

# %% [markdown]
# ### Operadores

# %%
def intersection_dicts(dict1, dict2):
    intersection = {}

    for key, value in dict2.items():
        if key in dict1:
            intersection[key] = value

    return intersection

# %% [markdown]
# ###### Operador OR

# %%
def operator_OR(doc1: str, doc2: str) -> dict:
    vector1 = {}
    vector2 = {}

    answer  = 0

    for term, posting in tf_idf.items():
        for node in posting.get_document_list():
            if node.name == doc1:
                vector1[term] = node.frequency
            if node.name == doc2:
                vector2[term] = node.frequency

    intersection = intersection_dicts(vector1, vector2)

    for term, frequency in intersection.items():
        answer += math.pow(frequency, 2)

    return math.sqrt(answer / len(intersection)) if len(intersection) > 0 else 0

query = 'estrutura de dados [AV - 2](3 - GABARITO).txt'

similarity = {}

for documento in document_token.keys():
    similarity[documento] = operator_OR(query, documento)

print(tabulate(sorted(similarity.items(), key=lambda item: item[1], reverse=True), headers=['Documento', 'Similaridade']))
# Out:
# Documento                                          Similaridade
# -----------------------------------------------  --------------
# grafos [AL - 3](2).txt                               0.348362
# estrutura de dados [AV - 2](2 - GABARITO).txt        0.31574
# estrutura de dados [AV - 2](4 - GABARITO).txt        0.311105
# programacao orientada a objetos [CB - 1](1).txt      0.266251
# grafos [AL - 3](1).txt                               0.259868
# estrutura de dados [AV - 3](2 - GABARITO).txt        0.259266
# estrutura de dados [AV - 2](5 - GABARITO).txt        0.245316
# banco de dados [CB- 2](1).txt                        0.243762
# estrutura de dados [AV - 2](3 - GABARITO).txt        0.236438
# banco de dados [PL-SQL - 3](1).txt                   0.233814
# programacao orientada a objetos [CB - 2](5).txt      0.231782
# programacao orientada a objetos [CB - 3](4).txt      0.218515
# banco de dados [MR - 3](3).txt                       0.211961
# programacao orientada a objetos [CB - 1](4).txt      0.211055
# programacao orientada a objetos [CB - 3](6).txt      0.211055
# estrutura de dados [AV - 2](1 - GABARITO).txt        0.204441
# estrutura de dados [CA - 2](1 - GABARITO).txt        0.202554
# programacao orientada a objetos [CB - 2](7).txt      0.199197
# estrutura de dados [MO - 1](1 - GABARITO).txt        0.191559
# estrutura de dados [FL - 3](1).txt                   0.184806
# banco de dados [MR - 2](9).txt                       0.183611
# estrutura de dados [AV - 3](1 - GABARITO).txt        0.17628
# banco de dados [MR - 3](1).txt                       0.17122
# estrutura de dados [CA - 2](2 - GABARITO).txt        0.169758
# grafos [CB - 3](4).txt                               0.168876
# introducao a programacao [CB - 1](1).txt             0.166243
# grafos [AL - 3](3).txt                               0.166194
# banco de dados [PT - 3](2).txt                       0.160183
# banco de dados [AR - 2](1).txt                       0.158784
# introducao a programacao [CB - 3](1).txt             0.1571
# grafos [CB - 2](6).txt                               0.156104
# estrutura de dados [CA - 1](1).txt                   0.155738
# estrutura de dados [MO - 1](2).txt                   0.154388
# grafos [CB - 1](2).txt                               0.151378
# grafos [CB - 1](5).txt                               0.1491
# estrutura de dados [MB - 2](1).txt                   0.145294
# introducao a programacao [CB - 1](9).txt             0.143718
# estrutura de dados [FL - 1](1).txt                   0.143608
# programacao orientada a objetos [CB - 2](6).txt      0.135773
# programacao orientada a objetos [CB - 3](3).txt      0.135664
# estrutura de dados [FL - 3](3).txt                   0.133272
# introducao a programacao [CB - 3](2).txt             0.130092
# estrutura de dados [FL - 3](2).txt                   0.129447
# grafos [CB - 2](3).txt                               0.129405
# banco de dados [MR - 2](11).txt                      0.126363
# grafos [CB - 2](5).txt                               0.126134
# estrutura de dados [MO - 1](4).txt                   0.124237
# introducao a programacao [TD- 2](1).txt              0.123287
# grafos [CB - 2](1).txt                               0.121835
# banco de dados [MR - 2](10).txt                      0.121172
# estrutra de dados [CB - 1](1).txt                    0.120102
# estrutura de dados [MO - 2](1).txt                   0.115899
# grafos [CB - 3](2).txt                               0.115346
# banco de dados [PL-SQL - 3](2).txt                   0.110839
# grafos [CB - 1](4).txt                               0.107122
# introducao a programacao [CB - 1](4).txt             0.104311
# grafos [CA - 3](2).txt                               0.103419
# programacao orientada a objetos [PL - 1](2).txt      0.101188
# programacao orientada a objetos [CB - 1](3).txt      0.0990812
# programacao orientada a objetos [CB - 2](8).txt      0.095884
# programacao orientada a objetos [CB - 3](2).txt      0.0887485
# grafos [CB - 2](2).txt                               0.0857361
# programacao orientada a objetos [CB - 2](1).txt      0.0819745
# banco de dados [PT - 3](1).txt                       0.0799892
# estrutura de dados [MO - 1](3).txt                   0.0798711
# banco de dados [MR - 1](6).txt                       0.0792927
# programacao orientada a objetos [CB - 1](2).txt      0.0787591
# programacao orientada a objetos [CB - 2](2).txt      0.0773235
# introducao a programacao [CB - 2](1).txt             0.0764527
# banco de dados [MR - 1](4).txt                       0.0756149
# programacao orientada a objetos [CL- 2](1).txt       0.0744169
# banco de dados [MR - 1](5).txt                       0.0736527
# banco de dados [MR - 2](8).txt                       0.070423
# programacao orientada a objetos [CB - 3](5).txt      0.0664482
# banco de dados [PL-SQL - 2](3).txt                   0.0617888
# programacao orientada a objetos [CB - 3](1).txt      0.0574153
# grafos [CA - 3](1).txt                               0.0549603
# introducao a programacao [BB - 3](1).txt             0.0548967
# grafos [CB - 3](1).txt                               0.0499721
# programacao orientada a objetos [CB - 2](4).txt      0.0471085
# introducao a programacao [CB - 1](10).txt            0.0443933
# programacao orientada a objetos [PL - 1](1).txt      0.0433378
# banco de dados [AR - 2](2).txt                       0.0419448
# introducao a programacao [CL - 3](2).txt             0.0408197
# introducao a programacao [CL- 3](1).txt              0.0369592
# banco de dados [MR - 3](2).txt                       0.0344521
# introducao a programacao [CB - 1](2).txt             0.0340455
# introducao a programacao [CB - 1](8).txt             0.0336522
# banco de dados [MR - 1](7).txt                       0.0327577
# banco de dados [CB - 3](2).txt                       0.0227122
# introducao a programacao [CB - 1](7).txt             0.0191701
# grafos [CB - 1](1).txt                               0.0189653
# grafos [CB - 1](3).txt                               0.0189653
# grafos [CB - 3](3).txt                               0.0189653
# programacao orientada a objetos [CB - 2](3).txt      0.0189653
# introducao a programacao [CB - 1](3).txt             0.0127801
# introducao a programacao [PT- 2](2).txt              0.0127801
# introducao a programacao [CB - 1](6).txt             0.0118258
# introducao a programacao [CB - 1](5).txt             0.0110251
# grafos [CB - 2](4).txt                               0.0095361
# introducao a programacao [CB - 2](2).txt             0.00919448
# introducao a programacao [CB - 2](3).txt             0.00416651

# %%
def operator_AND(doc1: str, doc2: str) -> dict:
    vector1 = {}
    vector2 = {}

    answer  = 0

    for term, posting in tf_idf.items():
        for node in posting.get_document_list():
            if node.name == doc1:
                vector1[term] = node.frequency
            if node.name == doc2:
                vector2[term] = node.frequency

    intersection = intersection_dicts(vector1, vector2)

    for term, frequency in intersection.items():
        answer += math.pow(1 - frequency, 2)

    return math.sqrt(answer / len(intersection)) if len(intersection) > 0 else 0

query = 'estrutura de dados [AV - 2](3 - GABARITO).txt'

similarity = {}

for documento in document_token.keys():
    similarity[documento] = operator_AND(query, documento)

print(tabulate(sorted(similarity.items(), key=lambda item: item[1], reverse=True), headers=['Documento', 'Similaridade']))
# Out:
# Documento                                          Similaridade
# -----------------------------------------------  --------------
# introducao a programacao [CB - 2](3).txt               0.996776
# introducao a programacao [CB - 2](2).txt               0.99435
# grafos [CB - 2](4).txt                                 0.993347
# introducao a programacao [CB - 1](5).txt               0.992719
# introducao a programacao [CB - 1](6).txt               0.992273
# introducao a programacao [CB - 1](3).txt               0.992161
# introducao a programacao [PT- 2](2).txt                0.992161
# grafos [CB - 1](1).txt                                 0.989093
# grafos [CB - 1](3).txt                                 0.989093
# grafos [CB - 3](3).txt                                 0.989093
# programacao orientada a objetos [CB - 2](3).txt        0.989093
# introducao a programacao [CB - 1](7).txt               0.988281
# banco de dados [CB - 3](2).txt                         0.987878
# banco de dados [MR - 3](2).txt                         0.981438
# introducao a programacao [CB - 1](2).txt               0.980738
# introducao a programacao [CL- 3](1).txt                0.980694
# banco de dados [MR - 1](7).txt                         0.97892
# banco de dados [AR - 2](2).txt                         0.978085
# introducao a programacao [CB - 1](8).txt               0.977819
# programacao orientada a objetos [PL - 1](1).txt        0.976517
# programacao orientada a objetos [CB - 2](4).txt        0.976313
# introducao a programacao [CL - 3](2).txt               0.975161
# grafos [CB - 3](1).txt                                 0.973715
# introducao a programacao [CB - 1](10).txt              0.968791
# grafos [CA - 3](1).txt                                 0.964873
# banco de dados [MR - 1](4).txt                         0.96337
# introducao a programacao [CB - 2](1).txt               0.963036
# introducao a programacao [BB - 3](1).txt               0.961929
# programacao orientada a objetos [CB - 3](5).txt        0.958977
# banco de dados [PT - 3](1).txt                         0.958842
# banco de dados [MR - 2](8).txt                         0.95871
# programacao orientada a objetos [CB - 3](1).txt        0.958396
# banco de dados [PL-SQL - 2](3).txt                     0.95676
# banco de dados [MR - 1](6).txt                         0.955916
# programacao orientada a objetos [CB - 1](2).txt        0.954331
# programacao orientada a objetos [CB - 3](2).txt        0.953906
# programacao orientada a objetos [CL- 2](1).txt         0.952035
# introducao a programacao [CB - 1](4).txt               0.950458
# banco de dados [MR - 1](5).txt                         0.947008
# grafos [CB - 2](2).txt                                 0.946445
# programacao orientada a objetos [CB - 2](1).txt        0.944753
# estrutura de dados [MO - 1](3).txt                     0.94471
# programacao orientada a objetos [CB - 1](3).txt        0.94142
# programacao orientada a objetos [PL - 1](2).txt        0.938087
# grafos [CA - 3](2).txt                                 0.937934
# programacao orientada a objetos [CB - 2](2).txt        0.937617
# introducao a programacao [CB - 1](9).txt               0.934461
# banco de dados [MR - 2](11).txt                        0.932609
# grafos [CB - 1](4).txt                                 0.930189
# introducao a programacao [CB - 3](1).txt               0.929847
# programacao orientada a objetos [CB - 2](8).txt        0.928496
# banco de dados [MR - 2](10).txt                        0.927634
# grafos [CB - 2](6).txt                                 0.927459
# estrutura de dados [MO - 2](1).txt                     0.926607
# banco de dados [PL-SQL - 3](2).txt                     0.923873
# grafos [CB - 3](2).txt                                 0.923376
# banco de dados [AR - 2](1).txt                         0.921923
# programacao orientada a objetos [CB - 3](3).txt        0.921662
# grafos [CB - 2](1).txt                                 0.921249
# grafos [CB - 2](5).txt                                 0.920821
# estrutura de dados [FL - 3](2).txt                     0.919562
# introducao a programacao [TD- 2](1).txt                0.917487
# estrutura de dados [MO - 1](4).txt                     0.914507
# estrutura de dados [FL - 3](3).txt                     0.912539
# estrutra de dados [CB - 1](1).txt                      0.911886
# estrutura de dados [MB - 2](1).txt                     0.911506
# estrutura de dados [FL - 1](1).txt                     0.91061
# grafos [CB - 2](3).txt                                 0.910541
# introducao a programacao [CB - 3](2).txt               0.908905
# introducao a programacao [CB - 1](1).txt               0.908658
# banco de dados [MR - 2](9).txt                         0.904664
# programacao orientada a objetos [CB - 2](6).txt        0.902155
# grafos [CB - 1](2).txt                                 0.899699
# estrutura de dados [MO - 1](2).txt                     0.894319
# grafos [CB - 1](5).txt                                 0.894235
# estrutura de dados [CA - 1](1).txt                     0.892875
# grafos [AL - 3](3).txt                                 0.886211
# grafos [CB - 3](4).txt                                 0.886154
# banco de dados [PT - 3](2).txt                         0.884158
# programacao orientada a objetos [CB - 1](4).txt        0.883075
# programacao orientada a objetos [CB - 3](6).txt        0.883075
# estrutura de dados [FL - 3](1).txt                     0.881004
# estrutura de dados [AV - 3](1 - GABARITO).txt          0.879942
# estrutura de dados [CA - 2](2 - GABARITO).txt          0.875892
# banco de dados [MR - 3](1).txt                         0.872793
# banco de dados [MR - 3](3).txt                         0.861725
# programacao orientada a objetos [CB - 2](7).txt        0.857751
# estrutura de dados [MO - 1](1 - GABARITO).txt          0.85663
# programacao orientada a objetos [CB - 2](5).txt        0.84749
# grafos [AL - 3](2).txt                                 0.846719
# estrutura de dados [AV - 2](1 - GABARITO).txt          0.845572
# programacao orientada a objetos [CB - 3](4).txt        0.845438
# estrutura de dados [CA - 2](1 - GABARITO).txt          0.841598
# grafos [AL - 3](1).txt                                 0.840971
# banco de dados [PL-SQL - 3](1).txt                     0.836652
# banco de dados [CB- 2](1).txt                          0.830475
# estrutura de dados [AV - 3](2 - GABARITO).txt          0.824827
# programacao orientada a objetos [CB - 1](1).txt        0.821965
# estrutura de dados [AV - 2](3 - GABARITO).txt          0.811779
# estrutura de dados [AV - 2](5 - GABARITO).txt          0.805629
# estrutura de dados [AV - 2](4 - GABARITO).txt          0.761878
# estrutura de dados [AV - 2](2 - GABARITO).txt          0.761203
